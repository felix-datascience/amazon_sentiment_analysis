# %% [markdown]
# # Naive Bayes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import string
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, f1_score

import optuna
#optuna.logging.set_verbosity(optuna.logging.WARNING)
# Out:
# [nltk_data] Downloading package stopwords to /home/felix/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/felix/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# read data into pandas dataframe
#path = "data/video_games.tsv.gz"
#video_games = pd.read_csv(path, sep="\t", parse_dates=[14], on_bad_lines="skip")
train_balanced = pd.read_csv("data/balanced/train_balanced.csv")
val_balanced = pd.read_csv("data/balanced/val_balanced.csv")
train_stratified = pd.read_csv("data/stratified/train_stratified.csv")
val_stratified = pd.read_csv("data/stratified/val_stratified.csv")
test = pd.read_csv("data/test.csv")

display(train_balanced.head())
display(val_balanced.head())
display(train_stratified.head())
display(val_stratified.head())
display(test.head())
# Out:
#                                          full_review  star_rating
# 0  Only for Terminator enthusiasts I gave this ga...            2
# 1  Worked for a few months and the kids tore it ....            2
# 2              didnt work but received a full refund            2
# 3  Really good graphics for a game from 2005 Real...            4
# 4  was great until the band on top snapped in hal...            2
#                                          full_review  star_rating
# 0  Works Good This product works good. It allows ...            5
# 1                      The touch pad sucks on balls.            3
# 2  Not as good as Sniper Elite 2 (Xbox 360 versio...            3
# 3  It's a turn based game, so don't expect a lot ...            2
# 4   Package came quickly and the game is great. T...            5
#     index                                        full_review  star_rating
# 0   63042         Not working The CD is not working properly            2
# 1   40973                                      Awesome game.            5
# 2  330407  Do yourself a favor and by loose ones! Works g...            5
# 3   64545  Xbox live!! Xbox live!! We all know its the be...            5
# 4  293826  The kids love it. No complaints.  The kids lov...            5
#     index                                        full_review  star_rating
# 0  248410                                          Good Good            5
# 1  145340                                        It's awsome            5
# 2  201995                great works great use it every year            5
# 3  116305  Great game and with the extra tarot cards and ...            5
# 4  320353   The price was about the only thing good about...            3
#                                          full_review  star_rating
# 0  very fun game, good graphics and realistic dri...            5
# 1  Awesome Case I really like this case. When I w...            5
# 2                                         Great game            5
# 3  I ordered this by mistake thinking that I was ...            5
# 4  The game is very generic but fun my husband lo...            4

# %% [markdown]
# ## Text Preprocessing

# %%
# functions used for preprocessing

def tokenize_words(text):
    tokenized_text = word_tokenize(text)
    return tokenized_text

def remove_punctuation(text):
    text = str(text)
    punctiations = string.punctuation
    return text.translate(str.maketrans('', '', punctiations))

STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(plain_text):
    return ' '.join([word for word in plain_text.split() if word not in STOPWORDS])

def remove_spec_char(text):
    text = str(text)
    text = re.sub('[^a-zA-Z0-9]', ' ', text)
    text = re.sub('\s+', ' ', text)
    return text

#lemmatizer = WordNetLemmatizer()
#wordnet_map = {'N':wordnet.NOUN, 'V':wordnet.VERB, 'J':wordnet.ADJ, 'R':wordnet.ADV}
#def lemmatize_word(plain_text):
#    # Finind pos tags
#    pos_text = pos_tag(plain_text.split())
#    return ' '.join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_text])

ps = PorterStemmer()
def stem_words(text):
    return ' '.join([ps.stem(word) for word in text.split()])

# %%
# lowercase words
train_balanced["full_review"] = train_balanced["full_review"].str.lower()
val_balanced["full_review"] = val_balanced["full_review"].str.lower()
train_stratified["full_review"] = train_stratified["full_review"].str.lower()
val_stratified["full_review"] = val_stratified["full_review"].str.lower()
test["full_review"] = test["full_review"].str.lower()
# remove punctuation,...
train_balanced["full_review"] = train_balanced["full_review"].apply(remove_punctuation)
val_balanced["full_review"] = val_balanced["full_review"].apply(remove_punctuation)
train_stratified["full_review"] = train_stratified["full_review"].apply(remove_punctuation)
val_stratified["full_review"] = val_stratified["full_review"].apply(remove_punctuation)
test["full_review"] = test["full_review"].apply(remove_punctuation)
# ...special characters,...
train_balanced["full_review"] = train_balanced["full_review"].apply(remove_spec_char)
val_balanced["full_review"] = val_balanced["full_review"].apply(remove_spec_char)
train_stratified["full_review"] = train_stratified["full_review"].apply(remove_spec_char)
val_stratified["full_review"] = val_stratified["full_review"].apply(remove_spec_char)
test["full_review"] = test["full_review"].apply(remove_spec_char)
# ...and stopwords
train_balanced["full_review"] = train_balanced["full_review"].apply(remove_stopwords)
val_balanced["full_review"] = val_balanced["full_review"].apply(remove_stopwords)
train_stratified["full_review"] = train_stratified["full_review"].apply(remove_stopwords)
val_stratified["full_review"] = val_stratified["full_review"].apply(remove_stopwords)
test["full_review"] = test["full_review"].apply(remove_stopwords)
# apply stemming
train_balanced["full_review"] = train_balanced["full_review"].apply(stem_words)
val_balanced["full_review"] = val_balanced["full_review"].apply(stem_words)
train_stratified["full_review"] = train_stratified["full_review"].apply(stem_words)
val_stratified["full_review"] = val_stratified["full_review"].apply(stem_words)
test["full_review"] = test["full_review"].apply(stem_words)

display(train_balanced.head())
display(val_balanced.head())
display(train_stratified.head())
display(val_stratified.head())
display(test.head())
# Out:
#                                          full_review  star_rating
# 0  termin enthusiast gave game 2 star like termin...            2
# 1  work month kid tore work month kid tore wire g...            2
# 2                      didnt work receiv full refund            2
# 3  realli good graphic game 2005 realli good grap...            4
# 4  great band top snap half great band top snap h...            2
#                                          full_review  star_rating
# 0  work good product work good allow play donkey ...            5
# 1                                touch pad suck ball            3
# 2  good sniper elit 2 xbox 360 version fun somewh...            3
# 3  turn base game dont expect lot intens action v...            2
# 4  packag came quickli game great three sli game ...            5
#     index                                        full_review  star_rating
# 0   63042                              work cd work properli            2
# 1   40973                                        awesom game            5
# 2  330407  favor loos one work great made son happi get r...            5
# 3   64545  xbox live xbox live know best market price che...            5
# 4  293826                        kid love complaint kid love            5
#     index                                        full_review  star_rating
# 0  248410                                          good good            5
# 1  145340                                              awsom            5
# 2  201995                    great work great use everi year            5
# 3  116305  great game extra tarot card inflat great game ...            5
# 4  320353  price thing good game first similar past game ...            3
#                                          full_review  star_rating
# 0  fun game good graphic realist drive fun game g...            5
# 1  awesom case realli like case look one want cle...            5
# 2                                         great game            5
# 3  order mistak think get order mistak think get ...            5
# 4  game gener fun husband love dc univers love ga...            4

# %%
# prediction target
y_train_b = train_balanced["star_rating"].values
y_val_b = val_balanced["star_rating"].values
y_train_s = train_stratified["star_rating"].values
y_val_s = val_stratified["star_rating"].values
y_test = test["star_rating"].values

# %% [markdown]
# ## Feature generation
#
# ### Binary word occurence vectors

# %%
# binary word occurence vectors
binary_vectorizer_b = CountVectorizer(binary=True)
binary_vectorizer_s = CountVectorizer(binary=True)

X_train_binary_b = binary_vectorizer_b.fit_transform(train_balanced["full_review"])
X_val_binary_b = binary_vectorizer_b.transform(val_balanced["full_review"])
X_test_binary_b = binary_vectorizer_b.transform(test["full_review"])

X_train_binary_s = binary_vectorizer_s.fit_transform(train_stratified["full_review"])
X_val_binary_s = binary_vectorizer_s.transform(val_stratified["full_review"])
X_test_binary_s = binary_vectorizer_s.transform(test["full_review"])

print(f"number of terms (balanced data set): {len(binary_vectorizer_b.get_feature_names_out())}")
print(f"number of terms (stratified data set): {len(binary_vectorizer_s.get_feature_names_out())}")
# Out:
# number of terms (balanced data set): 24681
# number of terms (stratified data set): 19451

# %% [markdown]
# ### TF-IDF vectors

# %%
# if-idf vectors
tfidf_vectorizer_b = TfidfVectorizer()
tfidf_vectorizer_s = TfidfVectorizer()

X_train_tfidf_b = tfidf_vectorizer_b.fit_transform(train_balanced["full_review"])
X_val_tfidf_b = tfidf_vectorizer_b.transform(val_balanced["full_review"])
X_test_tfidf_b = tfidf_vectorizer_b.transform(test["full_review"])

X_train_tfidf_s = tfidf_vectorizer_s.fit_transform(train_stratified["full_review"])
X_val_tfidf_s = tfidf_vectorizer_s.transform(val_stratified["full_review"])
X_test_tfidf_s = tfidf_vectorizer_s.transform(test["full_review"])

print(f"number of terms (balanced data set): {len(tfidf_vectorizer_b.get_feature_names_out())}")
print(f"number of terms (stratified data set): {len(tfidf_vectorizer_s.get_feature_names_out())}")
# Out:
# number of terms (balanced data set): 24681
# number of terms (stratified data set): 19451

# %% [markdown]
# ## Random Forest Model
#
# Four different models are created:
#
# - **rf_binary_b**: trained on binary word occurence vectors created from balanced dataset
# - **rf_tfidf_b**: trained on tfidf vectors created from balanced dataset
# - **rf_binary_s**: trained on binary word occurence vectors created from stratified dataset
# - **rf_tfidf_s**: trained on tfidf vectors created from stratified dataset

# %%
model_configs = {
    "rf_binary_b": {"train_datasets": [X_train_binary_b, y_train_b], "val_datasets": [X_val_binary_b, y_val_b], "test_datasets": [X_test_binary_b, y_test], "max_features": None, "max_depth": None},
    "rf_tfidf_b": {"train_datasets": [X_train_tfidf_b, y_train_b], "val_datasets": [X_val_tfidf_b, y_val_b], "test_datasets": [X_test_tfidf_b, y_test], "max_features": None, "max_depth": None},
    "rf_binary_s": {"train_datasets": [X_train_binary_s, y_train_s], "val_datasets": [X_val_binary_s, y_val_s], "test_datasets": [X_test_binary_s, y_test], "max_features": None, "max_depth": None},
    "rf_tfidf_s": {"train_datasets": [X_train_tfidf_s, y_train_s], "val_datasets": [X_val_tfidf_s, y_val_s], "test_datasets": [X_test_tfidf_s, y_test], "max_features": None, "max_depth": None},
}

# %% [markdown]
# ### Hyperparameter Tuning

# %%
#fig, axs = plt.subplots(nrows=4, tight_layout=True, figsize=(6, 16))

# iterate over different model configurations
for i, (model_name, model_config) in enumerate(model_configs.items()):

    # optimize hyperparameter alpha
    def objective(trial):
        # initiate model with alpha suggestion by optuna
        rf = RandomForestClassifier(n_estimators=100, max_features=trial.suggest_int("max_features", 1, 5000), max_depth=trial.suggest_int("max_depth", 1, 20))
        # fit model
        X_train = model_config["train_datasets"][0]
        y_train = model_config["train_datasets"][1]
        rf.fit(X_train, y_train)
        # evaluate model on validation set
        X_val = model_config["val_datasets"][0]
        y_val = model_config["val_datasets"][1]
        y_pred = rf.predict(X_val)
        f1 = f1_score(y_val, y_pred, average="micro")
        return f1

    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=40)
    # best hyperparameter configuration
    optimal_max_features = study.best_trial.params["max_features"]
    optimal_max_depth = study.best_trial.params["max_depth"]
    model_configs[model_name]["max_features"] = optimal_max_features
    model_configs[model_name]["max_depth"] = optimal_max_depth
    # plot max features and max depth and f1-scores
    #axs[i].scatter([trial.params["alpha"] for trial in study.trials], [trial.value for trial in study.trials])
    #axs[i].set_title(model_name)
    #axs[i].set_xlabel("alpha")
    #axs[i].set_ylabel("f1-score")
# Out:
# [I 2023-05-23 19:38:47,164] A new study created in memory with name: no-name-55ad4afe-12eb-413a-af5c-850a889a5a99
# [I 2023-05-23 19:38:49,156] Trial 0 finished with value: 0.398 and parameters: {'max_features': 79, 'max_depth': 20}. Best is trial 0 with value: 0.398.
# [I 2023-05-23 19:39:18,688] Trial 1 finished with value: 0.42411111111111105 and parameters: {'max_features': 2531, 'max_depth': 18}. Best is trial 1 with value: 0.42411111111111105.
# [I 2023-05-23 19:39:28,434] Trial 2 finished with value: 0.415 and parameters: {'max_features': 2478, 'max_depth': 10}. Best is trial 1 with value: 0.42411111111111105.
# [I 2023-05-23 19:39:32,949] Trial 3 finished with value: 0.4311111111111111 and parameters: {'max_features': 393, 'max_depth': 16}. Best is trial 3 with value: 0.4311111111111111.
# [I 2023-05-23 19:39:56,271] Trial 4 finished with value: 0.42511111111111105 and parameters: {'max_features': 2655, 'max_depth': 15}. Best is trial 3 with value: 0.4311111111111111.
# [I 2023-05-23 19:40:27,774] Trial 5 finished with value: 0.40700000000000003 and parameters: {'max_features': 4869, 'max_depth': 14}. Best is trial 3 with value: 0.4311111111111111.
# [I 2023-05-23 19:40:28,791] Trial 6 finished with value: 0.3536666666666667 and parameters: {'max_features': 4387, 'max_depth': 2}. Best is trial 3 with value: 0.4311111111111111.
# [I 2023-05-23 19:40:58,484] Trial 7 finished with value: 0.409 and parameters: {'max_features': 4442, 'max_depth': 14}. Best is trial 3 with value: 0.4311111111111111.
# [I 2023-05-23 19:41:00,199] Trial 8 finished with value: 0.3913333333333333 and parameters: {'max_features': 2731, 'max_depth': 4}. Best is trial 3 with value: 0.4311111111111111.
# [I 2023-05-23 19:41:01,151] Trial 9 finished with value: 0.3988888888888889 and parameters: {'max_features': 1925, 'max_depth': 3}. Best is trial 3 with value: 0.4311111111111111.
# [I 2023-05-23 19:41:02,681] Trial 10 finished with value: 0.41444444444444445 and parameters: {'max_features': 385, 'max_depth': 9}. Best is trial 3 with value: 0.4311111111111111.
# [I 2023-05-23 19:41:13,941] Trial 11 finished with value: 0.44277777777777777 and parameters: {'max_features': 1170, 'max_depth': 15}. Best is trial 11 with value: 0.44277777777777777.
# [I 2023-05-23 19:41:28,188] Trial 12 finished with value: 0.44155555555555553 and parameters: {'max_features': 1172, 'max_depth': 17}. Best is trial 11 with value: 0.44277777777777777.
# [I 2023-05-23 19:41:36,438] Trial 13 finished with value: 0.42888888888888893 and parameters: {'max_features': 1306, 'max_depth': 12}. Best is trial 11 with value: 0.44277777777777777.
# [I 2023-05-23 19:41:54,982] Trial 14 finished with value: 0.44044444444444447 and parameters: {'max_features': 1114, 'max_depth': 20}. Best is trial 11 with value: 0.44277777777777777.
# [I 2023-05-23 19:41:57,457] Trial 15 finished with value: 0.4246666666666667 and parameters: {'max_features': 1271, 'max_depth': 7}. Best is trial 11 with value: 0.44277777777777777.
# [I 2023-05-23 19:42:33,053] Trial 16 finished with value: 0.42144444444444445 and parameters: {'max_features': 3512, 'max_depth': 17}. Best is trial 11 with value: 0.44277777777777777.
# [I 2023-05-23 19:42:43,761] Trial 17 finished with value: 0.42866666666666664 and parameters: {'max_features': 1815, 'max_depth': 12}. Best is trial 11 with value: 0.44277777777777777.
# [I 2023-05-23 19:42:55,845] Trial 18 finished with value: 0.45111111111111113 and parameters: {'max_features': 781, 'max_depth': 19}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:43:05,306] Trial 19 finished with value: 0.44266666666666665 and parameters: {'max_features': 617, 'max_depth': 19}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:43:15,891] Trial 20 finished with value: 0.42433333333333334 and parameters: {'max_features': 1761, 'max_depth': 12}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:43:26,008] Trial 21 finished with value: 0.4381111111111111 and parameters: {'max_features': 649, 'max_depth': 19}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:43:37,351] Trial 22 finished with value: 0.44555555555555554 and parameters: {'max_features': 811, 'max_depth': 18}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:43:46,774] Trial 23 finished with value: 0.43622222222222223 and parameters: {'max_features': 857, 'max_depth': 16}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:43:47,582] Trial 24 finished with value: 0.30566666666666664 and parameters: {'max_features': 9, 'max_depth': 18}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:44:00,050] Trial 25 finished with value: 0.43633333333333335 and parameters: {'max_features': 1555, 'max_depth': 14}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:44:21,987] Trial 26 finished with value: 0.42622222222222217 and parameters: {'max_features': 2153, 'max_depth': 16}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:44:56,480] Trial 27 finished with value: 0.4244444444444445 and parameters: {'max_features': 3151, 'max_depth': 18}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:45:09,186] Trial 28 finished with value: 0.44533333333333336 and parameters: {'max_features': 742, 'max_depth': 20}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:45:14,332] Trial 29 finished with value: 0.4424444444444444 and parameters: {'max_features': 293, 'max_depth': 20}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:45:28,262] Trial 30 finished with value: 0.4467777777777778 and parameters: {'max_features': 861, 'max_depth': 20}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:45:42,537] Trial 31 finished with value: 0.441 and parameters: {'max_features': 879, 'max_depth': 20}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:45:53,718] Trial 32 finished with value: 0.44044444444444447 and parameters: {'max_features': 742, 'max_depth': 19}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:45:57,424] Trial 33 finished with value: 0.4321111111111111 and parameters: {'max_features': 248, 'max_depth': 18}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:46:20,855] Trial 34 finished with value: 0.44044444444444447 and parameters: {'max_features': 1507, 'max_depth': 20}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:46:32,010] Trial 35 finished with value: 0.44066666666666665 and parameters: {'max_features': 884, 'max_depth': 17}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:47:00,474] Trial 36 finished with value: 0.4321111111111111 and parameters: {'max_features': 2171, 'max_depth': 19}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:47:01,478] Trial 37 finished with value: 0.4141111111111111 and parameters: {'max_features': 486, 'max_depth': 6}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:47:02,247] Trial 38 finished with value: 0.3191111111111111 and parameters: {'max_features': 9, 'max_depth': 17}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:47:16,510] Trial 39 finished with value: 0.4328888888888889 and parameters: {'max_features': 1522, 'max_depth': 15}. Best is trial 18 with value: 0.45111111111111113.
# [I 2023-05-23 19:47:16,510] A new study created in memory with name: no-name-ede21cbf-833a-4ee7-a9c6-93d19b5cc1ee
# [I 2023-05-23 19:47:20,490] Trial 0 finished with value: 0.3847777777777778 and parameters: {'max_features': 3303, 'max_depth': 5}. Best is trial 0 with value: 0.3847777777777778.
# [I 2023-05-23 19:47:38,687] Trial 1 finished with value: 0.4327777777777777 and parameters: {'max_features': 1923, 'max_depth': 16}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:48:21,697] Trial 2 finished with value: 0.41833333333333333 and parameters: {'max_features': 4285, 'max_depth': 19}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:48:35,578] Trial 3 finished with value: 0.41388888888888886 and parameters: {'max_features': 3222, 'max_depth': 11}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:48:36,322] Trial 4 finished with value: 0.38422222222222224 and parameters: {'max_features': 48, 'max_depth': 9}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:48:37,968] Trial 5 finished with value: 0.391 and parameters: {'max_features': 56, 'max_depth': 20}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:48:41,004] Trial 6 finished with value: 0.4121111111111111 and parameters: {'max_features': 1726, 'max_depth': 6}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:48:57,416] Trial 7 finished with value: 0.42377777777777775 and parameters: {'max_features': 2738, 'max_depth': 13}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:49:13,916] Trial 8 finished with value: 0.429 and parameters: {'max_features': 1951, 'max_depth': 15}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:49:30,547] Trial 9 finished with value: 0.4142222222222222 and parameters: {'max_features': 3415, 'max_depth': 12}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:49:31,218] Trial 10 finished with value: 0.37311111111111106 and parameters: {'max_features': 1118, 'max_depth': 1}. Best is trial 1 with value: 0.4327777777777777.
# [I 2023-05-23 19:49:45,942] Trial 11 finished with value: 0.4344444444444445 and parameters: {'max_features': 1764, 'max_depth': 15}. Best is trial 11 with value: 0.4344444444444445.
# [I 2023-05-23 19:49:57,083] Trial 12 finished with value: 0.4428888888888889 and parameters: {'max_features': 1045, 'max_depth': 16}. Best is trial 12 with value: 0.4428888888888889.
# [I 2023-05-23 19:50:07,469] Trial 13 finished with value: 0.44555555555555554 and parameters: {'max_features': 876, 'max_depth': 17}. Best is trial 13 with value: 0.44555555555555554.
# [I 2023-05-23 19:50:19,132] Trial 14 finished with value: 0.4451111111111111 and parameters: {'max_features': 930, 'max_depth': 18}. Best is trial 13 with value: 0.44555555555555554.
# [I 2023-05-23 19:50:30,155] Trial 15 finished with value: 0.4448888888888889 and parameters: {'max_features': 810, 'max_depth': 18}. Best is trial 13 with value: 0.44555555555555554.
# [I 2023-05-23 19:50:37,995] Trial 16 finished with value: 0.4457777777777778 and parameters: {'max_features': 560, 'max_depth': 18}. Best is trial 16 with value: 0.4457777777777778.
# [I 2023-05-23 19:50:45,973] Trial 17 finished with value: 0.4457777777777778 and parameters: {'max_features': 468, 'max_depth': 20}. Best is trial 16 with value: 0.4457777777777778.
# [I 2023-05-23 19:50:52,981] Trial 18 finished with value: 0.44222222222222224 and parameters: {'max_features': 391, 'max_depth': 20}. Best is trial 16 with value: 0.4457777777777778.
# [I 2023-05-23 19:51:05,477] Trial 19 finished with value: 0.39255555555555555 and parameters: {'max_features': 4440, 'max_depth': 9}. Best is trial 16 with value: 0.4457777777777778.
# [I 2023-05-23 19:51:16,534] Trial 20 finished with value: 0.4391111111111111 and parameters: {'max_features': 1427, 'max_depth': 14}. Best is trial 16 with value: 0.4457777777777778.
# [I 2023-05-23 19:51:23,819] Trial 21 finished with value: 0.44055555555555553 and parameters: {'max_features': 584, 'max_depth': 17}. Best is trial 16 with value: 0.4457777777777778.
# [I 2023-05-23 19:51:31,652] Trial 22 finished with value: 0.4468888888888889 and parameters: {'max_features': 455, 'max_depth': 20}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:51:37,823] Trial 23 finished with value: 0.4327777777777777 and parameters: {'max_features': 328, 'max_depth': 20}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:52:03,625] Trial 24 finished with value: 0.42844444444444446 and parameters: {'max_features': 2313, 'max_depth': 18}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:52:25,122] Trial 25 finished with value: 0.4421111111111111 and parameters: {'max_features': 1408, 'max_depth': 20}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:53:11,107] Trial 26 finished with value: 0.42377777777777775 and parameters: {'max_features': 4951, 'max_depth': 19}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:53:17,706] Trial 27 finished with value: 0.44055555555555553 and parameters: {'max_features': 524, 'max_depth': 17}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:53:29,053] Trial 28 finished with value: 0.42966666666666664 and parameters: {'max_features': 1449, 'max_depth': 14}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:53:29,582] Trial 29 finished with value: 0.3338888888888889 and parameters: {'max_features': 91, 'max_depth': 2}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:53:32,588] Trial 30 finished with value: 0.39666666666666667 and parameters: {'max_features': 2317, 'max_depth': 5}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:53:40,416] Trial 31 finished with value: 0.4358888888888889 and parameters: {'max_features': 625, 'max_depth': 17}. Best is trial 22 with value: 0.4468888888888889.
# [I 2023-05-23 19:53:56,982] Trial 32 finished with value: 0.4472222222222222 and parameters: {'max_features': 1142, 'max_depth': 19}. Best is trial 32 with value: 0.4472222222222222.
# [I 2023-05-23 19:54:13,143] Trial 33 finished with value: 0.44377777777777777 and parameters: {'max_features': 1204, 'max_depth': 19}. Best is trial 32 with value: 0.4472222222222222.
# [I 2023-05-23 19:54:18,328] Trial 34 finished with value: 0.4375555555555556 and parameters: {'max_features': 325, 'max_depth': 19}. Best is trial 32 with value: 0.4472222222222222.
# [I 2023-05-23 19:54:26,282] Trial 35 finished with value: 0.4471111111111111 and parameters: {'max_features': 766, 'max_depth': 16}. Best is trial 32 with value: 0.4472222222222222.
# [I 2023-05-23 19:54:35,090] Trial 36 finished with value: 0.4411111111111111 and parameters: {'max_features': 784, 'max_depth': 16}. Best is trial 32 with value: 0.4472222222222222.
# [I 2023-05-23 19:54:38,961] Trial 37 finished with value: 0.4176666666666667 and parameters: {'max_features': 1337, 'max_depth': 8}. Best is trial 32 with value: 0.4472222222222222.
# [I 2023-05-23 19:54:39,704] Trial 38 finished with value: 0.332 and parameters: {'max_features': 10, 'max_depth': 15}. Best is trial 32 with value: 0.4472222222222222.
# [I 2023-05-23 19:54:54,924] Trial 39 finished with value: 0.41788888888888887 and parameters: {'max_features': 2864, 'max_depth': 12}. Best is trial 32 with value: 0.4472222222222222.
# [I 2023-05-23 19:54:54,925] A new study created in memory with name: no-name-a365b1f9-3b6a-44e6-8bd8-6df91b3c2d99
# [I 2023-05-23 19:54:59,121] Trial 0 finished with value: 0.6684444444444444 and parameters: {'max_features': 1666, 'max_depth': 9}. Best is trial 0 with value: 0.6684444444444444.
# [I 2023-05-23 19:54:59,622] Trial 1 finished with value: 0.6572222222222223 and parameters: {'max_features': 136, 'max_depth': 4}. Best is trial 0 with value: 0.6684444444444444.
# [I 2023-05-23 19:55:06,561] Trial 2 finished with value: 0.6744444444444444 and parameters: {'max_features': 1026, 'max_depth': 15}. Best is trial 2 with value: 0.6744444444444444.
# [I 2023-05-23 19:55:07,094] Trial 3 finished with value: 0.6572222222222223 and parameters: {'max_features': 2074, 'max_depth': 1}. Best is trial 2 with value: 0.6744444444444444.
# [I 2023-05-23 19:55:27,697] Trial 4 finished with value: 0.6915555555555556 and parameters: {'max_features': 2471, 'max_depth': 19}. Best is trial 4 with value: 0.6915555555555556.
# [I 2023-05-23 19:55:56,364] Trial 5 finished with value: 0.6922222222222222 and parameters: {'max_features': 4197, 'max_depth': 19}. Best is trial 5 with value: 0.6922222222222222.
# [I 2023-05-23 19:55:58,030] Trial 6 finished with value: 0.6633333333333333 and parameters: {'max_features': 3278, 'max_depth': 4}. Best is trial 5 with value: 0.6922222222222222.
# [I 2023-05-23 19:56:26,102] Trial 7 finished with value: 0.6925555555555556 and parameters: {'max_features': 4374, 'max_depth': 18}. Best is trial 7 with value: 0.6925555555555556.
# [I 2023-05-23 19:56:31,223] Trial 8 finished with value: 0.6708888888888889 and parameters: {'max_features': 3845, 'max_depth': 7}. Best is trial 7 with value: 0.6925555555555556.
# [I 2023-05-23 19:56:35,304] Trial 9 finished with value: 0.6684444444444444 and parameters: {'max_features': 1018, 'max_depth': 11}. Best is trial 7 with value: 0.6925555555555556.
# [I 2023-05-23 19:56:56,259] Trial 10 finished with value: 0.6861111111111111 and parameters: {'max_features': 4805, 'max_depth': 14}. Best is trial 7 with value: 0.6925555555555556.
# [I 2023-05-23 19:57:29,633] Trial 11 finished with value: 0.6936666666666667 and parameters: {'max_features': 4979, 'max_depth': 20}. Best is trial 11 with value: 0.6936666666666667.
# [I 2023-05-23 19:58:03,311] Trial 12 finished with value: 0.6938888888888889 and parameters: {'max_features': 4856, 'max_depth': 20}. Best is trial 12 with value: 0.6938888888888889.
# [I 2023-05-23 19:58:21,200] Trial 13 finished with value: 0.6865555555555556 and parameters: {'max_features': 3226, 'max_depth': 15}. Best is trial 12 with value: 0.6938888888888889.
# [I 2023-05-23 19:58:52,543] Trial 14 finished with value: 0.6955555555555556 and parameters: {'max_features': 4822, 'max_depth': 20}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 19:59:13,400] Trial 15 finished with value: 0.6901111111111111 and parameters: {'max_features': 3395, 'max_depth': 17}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 19:59:29,302] Trial 16 finished with value: 0.6853333333333333 and parameters: {'max_features': 4007, 'max_depth': 13}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 19:59:54,637] Trial 17 finished with value: 0.6895555555555556 and parameters: {'max_features': 4628, 'max_depth': 17}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:00:22,830] Trial 18 finished with value: 0.6934444444444444 and parameters: {'max_features': 3744, 'max_depth': 20}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:00:39,960] Trial 19 finished with value: 0.6836666666666666 and parameters: {'max_features': 4992, 'max_depth': 12}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:00:46,469] Trial 20 finished with value: 0.6761111111111111 and parameters: {'max_features': 2766, 'max_depth': 9}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:01:20,314] Trial 21 finished with value: 0.6938888888888889 and parameters: {'max_features': 4943, 'max_depth': 20}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:01:43,465] Trial 22 finished with value: 0.6878888888888889 and parameters: {'max_features': 4403, 'max_depth': 16}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:02:15,079] Trial 23 finished with value: 0.6933333333333334 and parameters: {'max_features': 4587, 'max_depth': 20}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:02:41,073] Trial 24 finished with value: 0.6916666666666667 and parameters: {'max_features': 4118, 'max_depth': 18}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:03:03,626] Trial 25 finished with value: 0.6898888888888889 and parameters: {'max_features': 3630, 'max_depth': 17}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:03:24,851] Trial 26 finished with value: 0.6912222222222222 and parameters: {'max_features': 2888, 'max_depth': 18}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:03:56,875] Trial 27 finished with value: 0.6933333333333334 and parameters: {'max_features': 4563, 'max_depth': 20}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:04:17,685] Trial 28 finished with value: 0.6874444444444444 and parameters: {'max_features': 4272, 'max_depth': 15}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:04:27,659] Trial 29 finished with value: 0.679 and parameters: {'max_features': 4964, 'max_depth': 9}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:04:39,019] Trial 30 finished with value: 0.6841111111111111 and parameters: {'max_features': 1584, 'max_depth': 16}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:05:11,078] Trial 31 finished with value: 0.6944444444444444 and parameters: {'max_features': 4989, 'max_depth': 20}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:05:40,301] Trial 32 finished with value: 0.691 and parameters: {'max_features': 4690, 'max_depth': 19}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:06:07,258] Trial 33 finished with value: 0.6921111111111111 and parameters: {'max_features': 4674, 'max_depth': 18}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:06:09,939] Trial 34 finished with value: 0.6606666666666666 and parameters: {'max_features': 197, 'max_depth': 20}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:06:36,297] Trial 35 finished with value: 0.6934444444444444 and parameters: {'max_features': 4054, 'max_depth': 19}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:06:40,159] Trial 36 finished with value: 0.6674444444444444 and parameters: {'max_features': 4399, 'max_depth': 6}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:06:52,661] Trial 37 finished with value: 0.686 and parameters: {'max_features': 1938, 'max_depth': 16}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:06:53,467] Trial 38 finished with value: 0.6583333333333333 and parameters: {'max_features': 3583, 'max_depth': 2}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:07:22,895] Trial 39 finished with value: 0.6914444444444444 and parameters: {'max_features': 4811, 'max_depth': 19}. Best is trial 14 with value: 0.6955555555555556.
# [I 2023-05-23 20:07:22,895] A new study created in memory with name: no-name-75e7315e-42eb-4a46-a804-51d9cd860986
# [I 2023-05-23 20:07:26,843] Trial 0 finished with value: 0.6676666666666666 and parameters: {'max_features': 950, 'max_depth': 11}. Best is trial 0 with value: 0.6676666666666666.
# [I 2023-05-23 20:07:30,371] Trial 1 finished with value: 0.666 and parameters: {'max_features': 2583, 'max_depth': 6}. Best is trial 0 with value: 0.6676666666666666.
# [I 2023-05-23 20:07:38,322] Trial 2 finished with value: 0.6767777777777778 and parameters: {'max_features': 2572, 'max_depth': 10}. Best is trial 2 with value: 0.6767777777777778.
# [I 2023-05-23 20:07:39,103] Trial 3 finished with value: 0.6572222222222223 and parameters: {'max_features': 83, 'max_depth': 10}. Best is trial 2 with value: 0.6767777777777778.
# [I 2023-05-23 20:07:40,297] Trial 4 finished with value: 0.6584444444444445 and parameters: {'max_features': 830, 'max_depth': 5}. Best is trial 2 with value: 0.6767777777777778.
# [I 2023-05-23 20:07:51,162] Trial 5 finished with value: 0.6802222222222222 and parameters: {'max_features': 3316, 'max_depth': 11}. Best is trial 5 with value: 0.6802222222222222.
# [I 2023-05-23 20:08:13,387] Trial 6 finished with value: 0.6874444444444444 and parameters: {'max_features': 4215, 'max_depth': 16}. Best is trial 6 with value: 0.6874444444444444.
# [I 2023-05-23 20:08:14,687] Trial 7 finished with value: 0.6575555555555556 and parameters: {'max_features': 608, 'max_depth': 6}. Best is trial 6 with value: 0.6874444444444444.
# [I 2023-05-23 20:08:23,946] Trial 8 finished with value: 0.6805555555555556 and parameters: {'max_features': 764, 'max_depth': 20}. Best is trial 6 with value: 0.6874444444444444.
# [I 2023-05-23 20:08:44,123] Trial 9 finished with value: 0.6885555555555556 and parameters: {'max_features': 3421, 'max_depth': 16}. Best is trial 9 with value: 0.6885555555555556.
# [I 2023-05-23 20:09:11,601] Trial 10 finished with value: 0.691 and parameters: {'max_features': 4758, 'max_depth': 17}. Best is trial 10 with value: 0.691.
# [I 2023-05-23 20:09:39,406] Trial 11 finished with value: 0.6906666666666667 and parameters: {'max_features': 4989, 'max_depth': 17}. Best is trial 10 with value: 0.691.
# [I 2023-05-23 20:10:13,134] Trial 12 finished with value: 0.6925555555555556 and parameters: {'max_features': 4920, 'max_depth': 20}. Best is trial 12 with value: 0.6925555555555556.
# [I 2023-05-23 20:10:47,132] Trial 13 finished with value: 0.6931111111111111 and parameters: {'max_features': 4930, 'max_depth': 20}. Best is trial 13 with value: 0.6931111111111111.
# [I 2023-05-23 20:11:17,515] Trial 14 finished with value: 0.6935555555555556 and parameters: {'max_features': 4084, 'max_depth': 20}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:11:18,464] Trial 15 finished with value: 0.6572222222222223 and parameters: {'max_features': 3876, 'max_depth': 1}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:11:29,255] Trial 16 finished with value: 0.6798888888888889 and parameters: {'max_features': 1801, 'max_depth': 14}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:11:59,941] Trial 17 finished with value: 0.6912222222222222 and parameters: {'max_features': 4186, 'max_depth': 20}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:12:16,195] Trial 18 finished with value: 0.6862222222222222 and parameters: {'max_features': 3271, 'max_depth': 14}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:12:45,376] Trial 19 finished with value: 0.6917777777777778 and parameters: {'max_features': 4241, 'max_depth': 18}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:12:55,961] Trial 20 finished with value: 0.6824444444444444 and parameters: {'max_features': 1963, 'max_depth': 14}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:13:30,417] Trial 21 finished with value: 0.6923333333333334 and parameters: {'max_features': 4591, 'max_depth': 20}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:14:00,265] Trial 22 finished with value: 0.6921111111111111 and parameters: {'max_features': 4474, 'max_depth': 19}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:14:25,092] Trial 23 finished with value: 0.6918888888888889 and parameters: {'max_features': 3742, 'max_depth': 18}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:14:48,689] Trial 24 finished with value: 0.6871111111111111 and parameters: {'max_features': 4966, 'max_depth': 15}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:15:14,244] Trial 25 finished with value: 0.6903333333333334 and parameters: {'max_features': 3798, 'max_depth': 18}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:15:46,875] Trial 26 finished with value: 0.693 and parameters: {'max_features': 4608, 'max_depth': 20}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:16:03,255] Trial 27 finished with value: 0.683 and parameters: {'max_features': 4490, 'max_depth': 12}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:16:25,697] Trial 28 finished with value: 0.6897777777777778 and parameters: {'max_features': 3163, 'max_depth': 18}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:16:31,930] Trial 29 finished with value: 0.6715555555555556 and parameters: {'max_features': 2962, 'max_depth': 8}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:16:32,969] Trial 30 finished with value: 0.6572222222222223 and parameters: {'max_features': 3976, 'max_depth': 1}. Best is trial 14 with value: 0.6935555555555556.
# [I 2023-05-23 20:17:06,433] Trial 31 finished with value: 0.6937777777777778 and parameters: {'max_features': 4846, 'max_depth': 20}. Best is trial 31 with value: 0.6937777777777778.
# [I 2023-05-23 20:17:36,361] Trial 32 finished with value: 0.6917777777777778 and parameters: {'max_features': 4557, 'max_depth': 19}. Best is trial 31 with value: 0.6937777777777778.
# [I 2023-05-23 20:18:06,754] Trial 33 finished with value: 0.6914444444444444 and parameters: {'max_features': 4655, 'max_depth': 19}. Best is trial 31 with value: 0.6937777777777778.
# [I 2023-05-23 20:18:29,950] Trial 34 finished with value: 0.6898888888888889 and parameters: {'max_features': 4175, 'max_depth': 16}. Best is trial 31 with value: 0.6937777777777778.
# [I 2023-05-23 20:18:46,392] Trial 35 finished with value: 0.6904444444444444 and parameters: {'max_features': 2268, 'max_depth': 17}. Best is trial 31 with value: 0.6937777777777778.
# [I 2023-05-23 20:19:12,486] Trial 36 finished with value: 0.6914444444444444 and parameters: {'max_features': 3658, 'max_depth': 19}. Best is trial 31 with value: 0.6937777777777778.
# [I 2023-05-23 20:19:19,003] Trial 37 finished with value: 0.6754444444444444 and parameters: {'max_features': 1394, 'max_depth': 12}. Best is trial 31 with value: 0.6937777777777778.
# [I 2023-05-23 20:19:50,293] Trial 38 finished with value: 0.6923333333333334 and parameters: {'max_features': 4352, 'max_depth': 20}. Best is trial 31 with value: 0.6937777777777778.
# [I 2023-05-23 20:19:59,324] Trial 39 finished with value: 0.6723333333333333 and parameters: {'max_features': 4727, 'max_depth': 8}. Best is trial 31 with value: 0.6937777777777778.

# %% [markdown]
# ### Model Evaluation

# %%
for model_name, model_config in model_configs.items():
    # build model
    max_features = model_config["max_features"]
    max_depth = model_config["max_depth"]
    rf = RandomForestClassifier(max_depth=max_depth, max_features=max_features)
    # fit model
    X_train = model_config["train_datasets"][0]
    y_train = model_config["train_datasets"][1]
    rf.fit(X_train, y_train)
    # evaluate model on test set
    X_test = model_config["test_datasets"][0]
    y_test = model_config["test_datasets"][1]
    y_pred = rf.predict(X_test)
    f1 = f1_score(y_test, y_pred, average="micro")
    print(f"f1-score {model_name} (max_features={max_features}, max_depth={max_depth}): {f1}")
    print(classification_report(y_test, y_pred))
# Out:
# f1-score rf_binary_b (max_features=781, max_depth=19): 0.6041587353383732
#               precision    recall  f1-score   support
#
#            1       0.45      0.65      0.53     15453
#            2       0.16      0.26      0.20      6680
#            3       0.25      0.25      0.25     11173
#            4       0.26      0.34      0.29     22197
#            5       0.84      0.71      0.77    109980
#
#     accuracy                           0.60    165483
#    macro avg       0.39      0.44      0.41    165483
# weighted avg       0.66      0.60      0.63    165483
#
# f1-score rf_tfidf_b (max_features=1142, max_depth=19): 0.5683725820779174
#               precision    recall  f1-score   support
#
#            1       0.45      0.63      0.53     15453
#            2       0.15      0.30      0.20      6680
#            3       0.19      0.30      0.23     11173
#            4       0.25      0.35      0.29     22197
#            5       0.87      0.65      0.74    109980
#
#     accuracy                           0.57    165483
#    macro avg       0.38      0.44      0.40    165483
# weighted avg       0.67      0.57      0.61    165483
#
# f1-score rf_binary_s (max_features=4822, max_depth=20): 0.6998724944556238
#               precision    recall  f1-score   support
#
#            1       0.59      0.41      0.49     15453
#            2       0.28      0.01      0.01      6680
#            3       0.43      0.05      0.09     11173
#            4       0.34      0.02      0.04     22197
#            5       0.71      0.99      0.83    109980
#
#     accuracy                           0.70    165483
#    macro avg       0.47      0.30      0.29    165483
# weighted avg       0.62      0.70      0.61    165483
#
# f1-score rf_tfidf_s (max_features=4846, max_depth=20): 0.6992621598593209
#               precision    recall  f1-score   support
#
#            1       0.60      0.39      0.47     15453
#            2       0.31      0.01      0.01      6680
#            3       0.45      0.06      0.10     11173
#            4       0.37      0.01      0.03     22197
#            5       0.71      0.99      0.83    109980
#
#     accuracy                           0.70    165483
#    macro avg       0.49      0.29      0.29    165483
# weighted avg       0.62      0.70      0.60    165483

# %%
# baseline for comparison
# (predict 5 stars for every review)
print(f"f1-score baseline: {f1_score(y_test, [5 for _ in range(len(y_test))], average='micro')}")
# Out:
# f1-score baseline: 0.6645999891227498
